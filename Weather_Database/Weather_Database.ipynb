# %% [markdown]
# ### Retrieve Weather Data

# %%
# Import the Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import requests library
import requests

# Import api key
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lat = np.random.uniform(low=-90.00, high=90.00, size=2000)
lng = np.random.uniform(low=-90.00, high=90.00, size=2000)
lat_lng = zip(lat,lng)
lat_lng

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lng)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 726

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Weather" : city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | saint-joseph
# Processing Record 3 of Set 1 | iqaluit
# Processing Record 4 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 1 | yaremche
# Processing Record 6 of Set 1 | vila velha
# Processing Record 7 of Set 1 | hermanus
# Processing Record 8 of Set 1 | arraial do cabo
# Processing Record 9 of Set 1 | mazara del vallo
# Processing Record 10 of Set 1 | dikson
# Processing Record 11 of Set 1 | alexander city
# Processing Record 12 of Set 1 | khor
# Processing Record 13 of Set 1 | dwarka
# Processing Record 14 of Set 1 | lebu
# Processing Record 15 of Set 1 | ulagan
# Processing Record 16 of Set 1 | torbay
# Processing Record 17 of Set 1 | jujuy
# City not found. Skipping...
# Processing Record 18 of Set 1 | gao
# Processing Record 19 of Set 1 | port alfred
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | zheleznodorozhnyy
# Processing Record 22 of Set 1 | jamestown
# Processing Record 23 of Set 1 | saint-philippe
# Processing Record 24 of Set 1 | touros
# Processing Record 25 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 1 | bandarbeyla
# Processing Record 27 of Set 1 | bud
# Processing Record 28 of Set 1 | klaksvik
# Processing Record 29 of Set 1 | hambantota
# Processing Record 30 of Set 1 | kalmunai
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | uspenka
# Processing Record 33 of Set 1 | cidreira
# Processing Record 34 of Set 1 | jodhpur
# Processing Record 35 of Set 1 | bosaso
# Processing Record 36 of Set 1 | coihaique
# Processing Record 37 of Set 1 | grindavik
# Processing Record 38 of Set 1 | punta arenas
# Processing Record 39 of Set 1 | cururupu
# Processing Record 40 of Set 1 | duz
# City not found. Skipping...
# Processing Record 41 of Set 1 | constitucion
# Processing Record 42 of Set 1 | vestmannaeyjar
# Processing Record 43 of Set 1 | upernavik
# Processing Record 44 of Set 1 | pausesti
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | inhambane
# Processing Record 47 of Set 1 | khabary
# Processing Record 48 of Set 1 | caravelas
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | itapirapua
# Processing Record 1 of Set 2 | fenoarivo
# Processing Record 2 of Set 2 | eyl
# Processing Record 3 of Set 2 | busselton
# Processing Record 4 of Set 2 | alexandria
# Processing Record 5 of Set 2 | aksarka
# Processing Record 6 of Set 2 | ongandjera
# Processing Record 7 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 2 | can
# Processing Record 9 of Set 2 | dapaong
# Processing Record 10 of Set 2 | saint-francois
# Processing Record 11 of Set 2 | kilindoni
# Processing Record 12 of Set 2 | itarema
# Processing Record 13 of Set 2 | rawson
# Processing Record 14 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 2 | victoria
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | tatarsk
# Processing Record 18 of Set 2 | umm lajj
# Processing Record 19 of Set 2 | soligalich
# Processing Record 20 of Set 2 | qaanaaq
# Processing Record 21 of Set 2 | key west
# Processing Record 22 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 25 of Set 2 | ilulissat
# Processing Record 26 of Set 2 | sioux lookout
# Processing Record 27 of Set 2 | tasiilaq
# Processing Record 28 of Set 2 | clyde river
# Processing Record 29 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 2 | krasnoselkup
# Processing Record 31 of Set 2 | thompson
# Processing Record 32 of Set 2 | bereda
# Processing Record 33 of Set 2 | oxapampa
# Processing Record 34 of Set 2 | turbat
# Processing Record 35 of Set 2 | sergeyevka
# Processing Record 36 of Set 2 | alta floresta
# Processing Record 37 of Set 2 | sao joao da barra
# Processing Record 38 of Set 2 | opuwo
# Processing Record 39 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 2 | ostrovnoy
# Processing Record 41 of Set 2 | sao filipe
# Processing Record 42 of Set 2 | atlantic beach
# Processing Record 43 of Set 2 | ahmadpur
# Processing Record 44 of Set 2 | mosquera
# Processing Record 45 of Set 2 | asfi
# Processing Record 46 of Set 2 | ambilobe
# Processing Record 47 of Set 2 | midland
# Processing Record 48 of Set 2 | ondjiva
# Processing Record 49 of Set 2 | boca do acre
# Processing Record 50 of Set 2 | namibe
# Processing Record 1 of Set 3 | muros
# Processing Record 2 of Set 3 | belyy yar
# Processing Record 3 of Set 3 | lagoa
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | gharghoda
# Processing Record 6 of Set 3 | kalur kot
# Processing Record 7 of Set 3 | sorland
# Processing Record 8 of Set 3 | east london
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | cap-aux-meules
# Processing Record 11 of Set 3 | karaton
# Processing Record 12 of Set 3 | san juan
# Processing Record 13 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 14 of Set 3 | krasnooktyabrskiy
# Processing Record 15 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 16 of Set 3 | oranjemund
# Processing Record 17 of Set 3 | lyantonde
# Processing Record 18 of Set 3 | nouadhibou
# Processing Record 19 of Set 3 | saint-pierre
# Processing Record 20 of Set 3 | sur
# Processing Record 21 of Set 3 | havelock
# Processing Record 22 of Set 3 | porto novo
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | parkent
# Processing Record 25 of Set 3 | hofn
# Processing Record 26 of Set 3 | praia
# Processing Record 27 of Set 3 | kruisfontein
# Processing Record 28 of Set 3 | longyearbyen
# Processing Record 29 of Set 3 | rocha
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | douentza
# Processing Record 32 of Set 3 | beira
# Processing Record 33 of Set 3 | vardo
# Processing Record 34 of Set 3 | port-gentil
# Processing Record 35 of Set 3 | port-cartier
# Processing Record 36 of Set 3 | pirgos
# Processing Record 37 of Set 3 | zhanaozen
# Processing Record 38 of Set 3 | coquimbo
# Processing Record 39 of Set 3 | mecca
# Processing Record 40 of Set 3 | saldanha
# Processing Record 41 of Set 3 | najran
# Processing Record 42 of Set 3 | bashmakovo
# Processing Record 43 of Set 3 | serenje
# Processing Record 44 of Set 3 | quatre cocos
# Processing Record 45 of Set 3 | volax
# Processing Record 46 of Set 3 | bengkulu
# Processing Record 47 of Set 3 | trincomalee
# Processing Record 48 of Set 3 | sinnamary
# Processing Record 49 of Set 3 | jeremie
# Processing Record 50 of Set 3 | umm kaddadah
# Processing Record 1 of Set 4 | kidal
# Processing Record 2 of Set 4 | mahebourg
# Processing Record 3 of Set 4 | salta
# Processing Record 4 of Set 4 | fenoarivo atsinanana
# Processing Record 5 of Set 4 | xuddur
# Processing Record 6 of Set 4 | santa cruz
# Processing Record 7 of Set 4 | kilimatinde
# Processing Record 8 of Set 4 | olinda
# Processing Record 9 of Set 4 | santa fe
# Processing Record 10 of Set 4 | laguna
# Processing Record 11 of Set 4 | maragogi
# Processing Record 12 of Set 4 | leshukonskoye
# Processing Record 13 of Set 4 | alto longa
# Processing Record 14 of Set 4 | tromso
# Processing Record 15 of Set 4 | saint anthony
# Processing Record 16 of Set 4 | constantine
# Processing Record 17 of Set 4 | ponta do sol
# Processing Record 18 of Set 4 | port blair
# Processing Record 19 of Set 4 | san luis
# Processing Record 20 of Set 4 | tabuk
# Processing Record 21 of Set 4 | barkhan
# Processing Record 22 of Set 4 | chlorakas
# Processing Record 23 of Set 4 | artyom
# Processing Record 24 of Set 4 | kyshtovka
# Processing Record 25 of Set 4 | nuuk
# Processing Record 26 of Set 4 | fecamp
# Processing Record 27 of Set 4 | korla
# Processing Record 28 of Set 4 | bouar
# Processing Record 29 of Set 4 | dondo
# Processing Record 30 of Set 4 | navahrudak
# Processing Record 31 of Set 4 | taoudenni
# Processing Record 32 of Set 4 | isla mujeres
# Processing Record 33 of Set 4 | humberto de campos
# Processing Record 34 of Set 4 | escanaba
# Processing Record 35 of Set 4 | chuy
# Processing Record 36 of Set 4 | sao gabriel da cachoeira
# Processing Record 37 of Set 4 | spassk
# Processing Record 38 of Set 4 | souillac
# Processing Record 39 of Set 4 | qaqortoq
# Processing Record 40 of Set 4 | neuquen
# Processing Record 41 of Set 4 | somanda
# Processing Record 42 of Set 4 | agbor
# Processing Record 43 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 45 of Set 4 | ramshir
# Processing Record 46 of Set 4 | muyuka
# Processing Record 47 of Set 4 | marystown
# Processing Record 48 of Set 4 | carlisle
# Processing Record 49 of Set 4 | harper
# Processing Record 50 of Set 4 | cockburn town
# Processing Record 1 of Set 5 | nizhniy odes
# Processing Record 2 of Set 5 | bardiyah
# Processing Record 3 of Set 5 | les cayes
# Processing Record 4 of Set 5 | kiruna
# Processing Record 5 of Set 5 | abidjan
# Processing Record 6 of Set 5 | tabas
# Processing Record 7 of Set 5 | jatai
# Processing Record 8 of Set 5 | san miguel
# Processing Record 9 of Set 5 | agadir
# Processing Record 10 of Set 5 | tarko-sale
# Processing Record 11 of Set 5 | pithiviers
# Processing Record 12 of Set 5 | nortelandia
# Processing Record 13 of Set 5 | niteroi
# Processing Record 14 of Set 5 | kasempa
# Processing Record 15 of Set 5 | malakal
# Processing Record 16 of Set 5 | kirkwall
# Processing Record 17 of Set 5 | mandiana
# Processing Record 18 of Set 5 | labytnangi
# Processing Record 19 of Set 5 | linhares
# Processing Record 20 of Set 5 | hualmay
# Processing Record 21 of Set 5 | narsaq
# Processing Record 22 of Set 5 | menongue
# Processing Record 23 of Set 5 | veraval
# Processing Record 24 of Set 5 | santo tomas
# Processing Record 25 of Set 5 | khorixas
# Processing Record 26 of Set 5 | yarmouth
# Processing Record 27 of Set 5 | kibaha
# Processing Record 28 of Set 5 | kavaratti
# Processing Record 29 of Set 5 | batsfjord
# Processing Record 30 of Set 5 | faya
# Processing Record 31 of Set 5 | porto santo
# Processing Record 32 of Set 5 | bambous virieux
# Processing Record 33 of Set 5 | irbit
# Processing Record 34 of Set 5 | pisco
# Processing Record 35 of Set 5 | santiago de cao
# Processing Record 36 of Set 5 | voskresenskoye
# Processing Record 37 of Set 5 | masumbwe
# Processing Record 38 of Set 5 | maceio
# Processing Record 39 of Set 5 | kananga
# Processing Record 40 of Set 5 | hamilton
# Processing Record 41 of Set 5 | cap malheureux
# Processing Record 42 of Set 5 | severnyy
# Processing Record 43 of Set 5 | mahibadhoo
# Processing Record 44 of Set 5 | trairi
# Processing Record 45 of Set 5 | cayenne
# Processing Record 46 of Set 5 | zhanakorgan
# Processing Record 47 of Set 5 | kantunilkin
# Processing Record 48 of Set 5 | ugoofaaru
# Processing Record 49 of Set 5 | helsinge
# Processing Record 50 of Set 5 | shorewood
# Processing Record 1 of Set 6 | sohbatpur
# Processing Record 2 of Set 6 | pitanga
# Processing Record 3 of Set 6 | kharovsk
# Processing Record 4 of Set 6 | kattivakkam
# Processing Record 5 of Set 6 | pitimbu
# Processing Record 6 of Set 6 | goderich
# Processing Record 7 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 6 | kanniyakumari
# Processing Record 9 of Set 6 | oudtshoorn
# Processing Record 10 of Set 6 | atar
# Processing Record 11 of Set 6 | pemba
# Processing Record 12 of Set 6 | salalah
# Processing Record 13 of Set 6 | milledgeville
# Processing Record 14 of Set 6 | usinsk
# Processing Record 15 of Set 6 | yara
# Processing Record 16 of Set 6 | rapla
# Processing Record 17 of Set 6 | paamiut
# Processing Record 18 of Set 6 | biltine
# Processing Record 19 of Set 6 | totness
# Processing Record 20 of Set 6 | areia branca
# Processing Record 21 of Set 6 | lodja
# Processing Record 22 of Set 6 | talcahuano
# Processing Record 23 of Set 6 | loharu
# Processing Record 24 of Set 6 | kosh-agach
# Processing Record 25 of Set 6 | carnarvon
# Processing Record 26 of Set 6 | oksfjord
# Processing Record 27 of Set 6 | kita
# Processing Record 28 of Set 6 | manavalakurichi
# Processing Record 29 of Set 6 | chapleau
# Processing Record 30 of Set 6 | anar darreh
# City not found. Skipping...
# Processing Record 31 of Set 6 | kalabo
# Processing Record 32 of Set 6 | aasiaat
# Processing Record 33 of Set 6 | angoche
# Processing Record 34 of Set 6 | damietta
# Processing Record 35 of Set 6 | lucapa
# Processing Record 36 of Set 6 | kintampo
# Processing Record 37 of Set 6 | dalvik
# Processing Record 38 of Set 6 | stornoway
# Processing Record 39 of Set 6 | zadonsk
# Processing Record 40 of Set 6 | aksu
# Processing Record 41 of Set 6 | hammerfest
# Processing Record 42 of Set 6 | ipora
# Processing Record 43 of Set 6 | mungwi
# Processing Record 44 of Set 6 | raga
# Processing Record 45 of Set 6 | kastornoye
# Processing Record 46 of Set 6 | dingle
# Processing Record 47 of Set 6 | roald
# Processing Record 48 of Set 6 | derzhavinsk
# Processing Record 49 of Set 6 | pafos
# Processing Record 50 of Set 6 | balila
# Processing Record 1 of Set 7 | akcakoca
# Processing Record 2 of Set 7 | porto empedocle
# Processing Record 3 of Set 7 | yalta
# Processing Record 4 of Set 7 | comodoro rivadavia
# Processing Record 5 of Set 7 | maryville
# Processing Record 6 of Set 7 | arlit
# Processing Record 7 of Set 7 | ewo
# Processing Record 8 of Set 7 | hobyo
# Processing Record 9 of Set 7 | marica
# Processing Record 10 of Set 7 | mossoro
# Processing Record 11 of Set 7 | benghazi
# Processing Record 12 of Set 7 | itacarambi
# Processing Record 13 of Set 7 | chimbote
# Processing Record 14 of Set 7 | ziarat
# Processing Record 15 of Set 7 | vestmanna
# Processing Record 16 of Set 7 | ribas do rio pardo
# Processing Record 17 of Set 7 | taiobeiras
# Processing Record 18 of Set 7 | ancud
# Processing Record 19 of Set 7 | pimentel
# Processing Record 20 of Set 7 | abay
# Processing Record 21 of Set 7 | nantucket
# Processing Record 22 of Set 7 | samana
# Processing Record 23 of Set 7 | knysna
# Processing Record 24 of Set 7 | muli
# Processing Record 25 of Set 7 | parczew
# Processing Record 26 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 27 of Set 7 | ostersund
# Processing Record 28 of Set 7 | cotacachi
# Processing Record 29 of Set 7 | codrington
# Processing Record 30 of Set 7 | ponta delgada
# Processing Record 31 of Set 7 | garissa
# Processing Record 32 of Set 7 | mantua
# Processing Record 33 of Set 7 | qasigiannguit
# Processing Record 34 of Set 7 | pangnirtung
# Processing Record 35 of Set 7 | eyrarbakki
# Processing Record 36 of Set 7 | tacuarembo
# Processing Record 37 of Set 7 | bathsheba
# Processing Record 38 of Set 7 | halifax
# Processing Record 39 of Set 7 | edea
# Processing Record 40 of Set 7 | niono
# Processing Record 41 of Set 7 | gilgit
# Processing Record 42 of Set 7 | ibra
# Processing Record 43 of Set 7 | alenquer
# Processing Record 44 of Set 7 | rorvik
# Processing Record 45 of Set 7 | vila franca do campo
# Processing Record 46 of Set 7 | el alto
# Processing Record 47 of Set 7 | yar-sale
# Processing Record 48 of Set 7 | shakiso
# Processing Record 49 of Set 7 | iisalmi
# Processing Record 50 of Set 7 | mahe
# Processing Record 1 of Set 8 | talara
# Processing Record 2 of Set 8 | saint-leu
# Processing Record 3 of Set 8 | kindberg
# Processing Record 4 of Set 8 | pandamatenga
# Processing Record 5 of Set 8 | besikduzu
# Processing Record 6 of Set 8 | bonthe
# Processing Record 7 of Set 8 | abu zabad
# Processing Record 8 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 9 of Set 8 | netivot
# Processing Record 10 of Set 8 | mapiri
# Processing Record 11 of Set 8 | galle
# Processing Record 12 of Set 8 | chor
# Processing Record 13 of Set 8 | steubenville
# Processing Record 14 of Set 8 | abu samrah
# Processing Record 15 of Set 8 | mehamn
# Processing Record 16 of Set 8 | gat
# Processing Record 17 of Set 8 | los llanos de aridane
# Processing Record 18 of Set 8 | beyneu
# Processing Record 19 of Set 8 | ilebo
# Processing Record 20 of Set 8 | opobo
# City not found. Skipping...
# Processing Record 21 of Set 8 | kumluca
# Processing Record 22 of Set 8 | tindivanam
# Processing Record 23 of Set 8 | prainha
# Processing Record 24 of Set 8 | lobva
# Processing Record 25 of Set 8 | talnakh
# Processing Record 26 of Set 8 | araguatins
# City not found. Skipping...
# Processing Record 27 of Set 8 | wamba
# Processing Record 28 of Set 8 | contamana
# Processing Record 29 of Set 8 | kaka
# Processing Record 30 of Set 8 | tocopilla
# Processing Record 31 of Set 8 | alvinopolis
# Processing Record 32 of Set 8 | nanpara
# Processing Record 33 of Set 8 | havre-saint-pierre
# Processing Record 34 of Set 8 | albany
# Processing Record 35 of Set 8 | agadez
# Processing Record 36 of Set 8 | iralaya
# Processing Record 37 of Set 8 | morondava
# Processing Record 38 of Set 8 | arvi
# Processing Record 39 of Set 8 | axim
# Processing Record 40 of Set 8 | sakakah
# Processing Record 41 of Set 8 | saint-augustin
# Processing Record 42 of Set 8 | rabo de peixe
# Processing Record 43 of Set 8 | nanortalik
# Processing Record 44 of Set 8 | luneville
# Processing Record 45 of Set 8 | vilhena
# Processing Record 46 of Set 8 | yenagoa
# Processing Record 47 of Set 8 | chivay
# Processing Record 48 of Set 8 | gordeyevka
# Processing Record 49 of Set 8 | luanda
# Processing Record 50 of Set 8 | necochea
# Processing Record 1 of Set 9 | saint george
# Processing Record 2 of Set 9 | brigantine
# Processing Record 3 of Set 9 | black river
# Processing Record 4 of Set 9 | andenes
# Processing Record 5 of Set 9 | buraydah
# Processing Record 6 of Set 9 | almeria
# Processing Record 7 of Set 9 | warrington
# Processing Record 8 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 9 | san joaquin
# Processing Record 10 of Set 9 | calama
# Processing Record 11 of Set 9 | florencia
# Processing Record 12 of Set 9 | vieques
# Processing Record 13 of Set 9 | basoko
# Processing Record 14 of Set 9 | pavilosta
# Processing Record 15 of Set 9 | monrovia
# Processing Record 16 of Set 9 | khorramshahr
# Processing Record 17 of Set 9 | joensuu
# Processing Record 18 of Set 9 | sabha
# Processing Record 19 of Set 9 | havoysund
# Processing Record 20 of Set 9 | malinyi
# Processing Record 21 of Set 9 | petropavl
# Processing Record 22 of Set 9 | surt
# Processing Record 23 of Set 9 | coevorden
# Processing Record 24 of Set 9 | ceres
# Processing Record 25 of Set 9 | roquetas de mar
# Processing Record 26 of Set 9 | guanare
# Processing Record 27 of Set 9 | olafsvik
# Processing Record 28 of Set 9 | marsh harbour
# Processing Record 29 of Set 9 | bubaque
# Processing Record 30 of Set 9 | grand gaube
# Processing Record 31 of Set 9 | saquarema
# Processing Record 32 of Set 9 | ostrow mazowiecka
# Processing Record 33 of Set 9 | richards bay
# Processing Record 34 of Set 9 | winsford
# Processing Record 35 of Set 9 | verkhnyaya inta
# Processing Record 36 of Set 9 | jizan
# Processing Record 37 of Set 9 | kaspiyskiy
# Processing Record 38 of Set 9 | myrhorod
# Processing Record 39 of Set 9 | peniche
# Processing Record 40 of Set 9 | sinop
# Processing Record 41 of Set 9 | jamai
# Processing Record 42 of Set 9 | mancheral
# Processing Record 43 of Set 9 | mbaiki
# Processing Record 44 of Set 9 | karauzyak
# City not found. Skipping...
# Processing Record 45 of Set 9 | bhakkar
# Processing Record 46 of Set 9 | akhalgori
# Processing Record 47 of Set 9 | itigi
# Processing Record 48 of Set 9 | barreirinhas
# Processing Record 49 of Set 9 | camana
# Processing Record 50 of Set 9 | trelew
# Processing Record 1 of Set 10 | khanpur
# Processing Record 2 of Set 10 | gazanjyk
# Processing Record 3 of Set 10 | kibala
# Processing Record 4 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 5 of Set 10 | peterhead
# Processing Record 6 of Set 10 | bermejo
# Processing Record 7 of Set 10 | benguela
# Processing Record 8 of Set 10 | jumla
# Processing Record 9 of Set 10 | nkongsamba
# Processing Record 10 of Set 10 | eshowe
# Processing Record 11 of Set 10 | shakhtinsk
# Processing Record 12 of Set 10 | baragua
# Processing Record 13 of Set 10 | takoradi
# Processing Record 14 of Set 10 | aqtobe
# Processing Record 15 of Set 10 | paita
# Processing Record 16 of Set 10 | ghanzi
# Processing Record 17 of Set 10 | koutsouras
# Processing Record 18 of Set 10 | sechura
# Processing Record 19 of Set 10 | sessa aurunca
# Processing Record 20 of Set 10 | constanza
# Processing Record 21 of Set 10 | newry
# Processing Record 22 of Set 10 | chistogorskiy
# Processing Record 23 of Set 10 | gamba
# Processing Record 24 of Set 10 | litoral del san juan
# City not found. Skipping...
# Processing Record 25 of Set 10 | beloha
# Processing Record 26 of Set 10 | jurilovca
# Processing Record 27 of Set 10 | baghdad
# Processing Record 28 of Set 10 | polunochnoye
# Processing Record 29 of Set 10 | makokou
# Processing Record 30 of Set 10 | cadiz
# Processing Record 31 of Set 10 | bandar-e anzali
# Processing Record 32 of Set 10 | grootfontein
# Processing Record 33 of Set 10 | severodvinsk
# Processing Record 34 of Set 10 | sahrak
# City not found. Skipping...
# Processing Record 35 of Set 10 | baherden
# Processing Record 36 of Set 10 | sehithwa
# Processing Record 37 of Set 10 | leirvik
# Processing Record 38 of Set 10 | togur
# Processing Record 39 of Set 10 | onega
# Processing Record 40 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 41 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 42 of Set 10 | valdivia
# Processing Record 43 of Set 10 | olot
# Processing Record 44 of Set 10 | rio gallegos
# Processing Record 45 of Set 10 | shache
# Processing Record 46 of Set 10 | dunmore town
# Processing Record 47 of Set 10 | joshimath
# Processing Record 48 of Set 10 | coesfeld
# Processing Record 49 of Set 10 | bodden town
# Processing Record 50 of Set 10 | carutapera
# Processing Record 1 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 2 of Set 11 | ouro preto do oeste
# Processing Record 3 of Set 11 | walvis bay
# Processing Record 4 of Set 11 | ilhabela
# Processing Record 5 of Set 11 | ahtopol
# Processing Record 6 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 7 of Set 11 | danville
# Processing Record 8 of Set 11 | acarau
# Processing Record 9 of Set 11 | sadovoye
# Processing Record 10 of Set 11 | miquelon
# Processing Record 11 of Set 11 | sayyan
# Processing Record 12 of Set 11 | bondo
# Processing Record 13 of Set 11 | skiros
# City not found. Skipping...
# Processing Record 14 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 15 of Set 11 | husavik
# Processing Record 16 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 11 | ilo
# Processing Record 18 of Set 11 | brokopondo
# Processing Record 19 of Set 11 | kondinskoye
# Processing Record 20 of Set 11 | vyartsilya
# Processing Record 21 of Set 11 | chabahar
# Processing Record 22 of Set 11 | kismayo
# Processing Record 23 of Set 11 | santa pola
# Processing Record 24 of Set 11 | camacupa
# Processing Record 25 of Set 11 | torres novas
# Processing Record 26 of Set 11 | freeport
# Processing Record 27 of Set 11 | tessalit
# Processing Record 28 of Set 11 | chokwe
# Processing Record 29 of Set 11 | alakurtti
# Processing Record 30 of Set 11 | tutoia
# Processing Record 31 of Set 11 | aracati
# Processing Record 32 of Set 11 | mogadishu
# Processing Record 33 of Set 11 | taki
# Processing Record 34 of Set 11 | yarovoye
# Processing Record 35 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 11 | kasane
# Processing Record 37 of Set 11 | koppies
# Processing Record 38 of Set 11 | tabou
# Processing Record 39 of Set 11 | santa maria
# Processing Record 40 of Set 11 | amol
# Processing Record 41 of Set 11 | vvedenskoye
# Processing Record 42 of Set 11 | puerto colombia
# Processing Record 43 of Set 11 | jalu
# Processing Record 44 of Set 11 | bagotville
# Processing Record 45 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 46 of Set 11 | tirur
# Processing Record 47 of Set 11 | sandavagur
# City not found. Skipping...
# Processing Record 48 of Set 11 | whitley bay
# Processing Record 49 of Set 11 | amalapuram
# Processing Record 50 of Set 11 | burgeo
# Processing Record 1 of Set 12 | yako
# Processing Record 2 of Set 12 | kuyanovo
# Processing Record 3 of Set 12 | aleksandrovskoye
# Processing Record 4 of Set 12 | chapais
# Processing Record 5 of Set 12 | mount pleasant
# Processing Record 6 of Set 12 | marquard
# Processing Record 7 of Set 12 | plettenberg bay
# Processing Record 8 of Set 12 | calabozo
# Processing Record 9 of Set 12 | trinidad
# Processing Record 10 of Set 12 | portobelo
# Processing Record 11 of Set 12 | mulchen
# Processing Record 12 of Set 12 | swabi
# Processing Record 13 of Set 12 | skjaerhollen
# City not found. Skipping...
# Processing Record 14 of Set 12 | aswan
# Processing Record 15 of Set 12 | la asuncion
# Processing Record 16 of Set 12 | coruripe
# Processing Record 17 of Set 12 | paidha
# Processing Record 18 of Set 12 | vidalia
# Processing Record 19 of Set 12 | pedernales
# Processing Record 20 of Set 12 | sept-iles
# Processing Record 21 of Set 12 | maldonado
# Processing Record 22 of Set 12 | kadoma
# Processing Record 23 of Set 12 | kulpahar
# Processing Record 24 of Set 12 | voznesenye
# Processing Record 25 of Set 12 | marfino
# Processing Record 26 of Set 12 | suez
# Processing Record 27 of Set 12 | lakewood
# Processing Record 28 of Set 12 | nuristan
# Processing Record 29 of Set 12 | vagur
# Processing Record 30 of Set 12 | wabana
# Processing Record 31 of Set 12 | mahanoro
# Processing Record 32 of Set 12 | amarante do maranhao
# Processing Record 33 of Set 12 | doha
# Processing Record 34 of Set 12 | peruibe
# Processing Record 35 of Set 12 | visby
# Processing Record 36 of Set 12 | changji
# Processing Record 37 of Set 12 | kedrovyy
# Processing Record 38 of Set 12 | keti bandar
# Processing Record 39 of Set 12 | ouallam
# Processing Record 40 of Set 12 | tiznit
# Processing Record 41 of Set 12 | marawi
# Processing Record 42 of Set 12 | sao paulo de olivenca
# Processing Record 43 of Set 12 | soledade
# Processing Record 44 of Set 12 | cartagena
# Processing Record 45 of Set 12 | lithakia
# Processing Record 46 of Set 12 | soyo
# Processing Record 47 of Set 12 | birnin kebbi
# Processing Record 48 of Set 12 | mpanda
# Processing Record 49 of Set 12 | bristol
# Processing Record 50 of Set 12 | ames
# Processing Record 1 of Set 13 | zurrieq
# Processing Record 2 of Set 13 | larsnes
# Processing Record 3 of Set 13 | tosya
# Processing Record 4 of Set 13 | paramonga
# Processing Record 5 of Set 13 | oussouye
# Processing Record 6 of Set 13 | aberfoyle
# Processing Record 7 of Set 13 | imbituba
# Processing Record 8 of Set 13 | garowe
# Processing Record 9 of Set 13 | igboho
# Processing Record 10 of Set 13 | nacala
# Processing Record 11 of Set 13 | meulaboh
# Processing Record 12 of Set 13 | elat
# Processing Record 13 of Set 13 | bondoukou
# Processing Record 14 of Set 13 | manavgat
# Processing Record 15 of Set 13 | bella union
# Processing Record 16 of Set 13 | itinga
# Processing Record 17 of Set 13 | ivanava
# Processing Record 18 of Set 13 | berlevag
# Processing Record 19 of Set 13 | brodowski
# Processing Record 20 of Set 13 | san cristobal
# Processing Record 21 of Set 13 | fort payne
# Processing Record 22 of Set 13 | camacha
# Processing Record 23 of Set 13 | teguise
# Processing Record 24 of Set 13 | maine-soroa
# Processing Record 25 of Set 13 | colombo
# Processing Record 26 of Set 13 | mangrol
# Processing Record 27 of Set 13 | rozhyshche
# Processing Record 28 of Set 13 | sharjah
# Processing Record 29 of Set 13 | trapani
# Processing Record 30 of Set 13 | tena
# Processing Record 31 of Set 13 | pangoa
# Processing Record 32 of Set 13 | huarmey
# Processing Record 33 of Set 13 | la peca
# Processing Record 34 of Set 13 | matara
# Processing Record 35 of Set 13 | koscian
# Processing Record 36 of Set 13 | thaba-tseka
# Processing Record 37 of Set 13 | itupiranga
# Processing Record 38 of Set 13 | odweyne
# Processing Record 39 of Set 13 | savannah bight
# Processing Record 40 of Set 13 | eydhafushi
# Processing Record 41 of Set 13 | forio
# Processing Record 42 of Set 13 | colquechaca
# Processing Record 43 of Set 13 | slonim
# Processing Record 44 of Set 13 | kudahuvadhoo
# Processing Record 45 of Set 13 | sinegorskiy
# Processing Record 46 of Set 13 | verkhnyaya sinyachikha
# Processing Record 47 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 48 of Set 13 | islamkot
# Processing Record 49 of Set 13 | jutai
# Processing Record 50 of Set 13 | cibitoke
# Processing Record 1 of Set 14 | blyth
# Processing Record 2 of Set 14 | ornskoldsvik
# Processing Record 3 of Set 14 | balad
# Processing Record 4 of Set 14 | presidencia roque saenz pena
# Processing Record 5 of Set 14 | naifaru
# Processing Record 6 of Set 14 | belmonte
# Processing Record 7 of Set 14 | arenapolis
# Processing Record 8 of Set 14 | beinamar
# Processing Record 9 of Set 14 | ghorawal
# Processing Record 10 of Set 14 | cancun
# Processing Record 11 of Set 14 | vilcun
# Processing Record 12 of Set 14 | conceicao da barra
# Processing Record 13 of Set 14 | bonfim
# Processing Record 14 of Set 14 | betare oya
# Processing Record 15 of Set 14 | yangambi
# Processing Record 16 of Set 14 | senanga
# Processing Record 17 of Set 14 | sistranda
# Processing Record 18 of Set 14 | filingue
# Processing Record 19 of Set 14 | smoljan
# Processing Record 20 of Set 14 | barbastro
# Processing Record 21 of Set 14 | umzimvubu
# City not found. Skipping...
# Processing Record 22 of Set 14 | agsu
# City not found. Skipping...
# Processing Record 23 of Set 14 | moyale
# Processing Record 24 of Set 14 | concord
# Processing Record 25 of Set 14 | medea
# Processing Record 26 of Set 14 | dakar
# Processing Record 27 of Set 14 | sanchursk
# Processing Record 28 of Set 14 | qeshm
# Processing Record 29 of Set 14 | pocoes
# Processing Record 30 of Set 14 | vozhd proletariata
# City not found. Skipping...
# Processing Record 31 of Set 14 | mana
# Processing Record 32 of Set 14 | cotonou
# Processing Record 33 of Set 14 | melfi
# Processing Record 34 of Set 14 | novoselitskoye
# Processing Record 35 of Set 14 | taraz
# Processing Record 36 of Set 14 | banepa
# Processing Record 37 of Set 14 | chardara
# Processing Record 38 of Set 14 | tazmalt
# Processing Record 39 of Set 14 | charyshskoye
# Processing Record 40 of Set 14 | kensington
# Processing Record 41 of Set 14 | turukhansk
# Processing Record 42 of Set 14 | zapolyarnyy
# Processing Record 43 of Set 14 | gabu
# Processing Record 44 of Set 14 | sao felix do xingu
# Processing Record 45 of Set 14 | carolina
# Processing Record 46 of Set 14 | bulqize
# Processing Record 47 of Set 14 | manzil salim
# Processing Record 48 of Set 14 | gandia
# Processing Record 49 of Set 14 | grand-santi
# Processing Record 50 of Set 14 | dubovskoye
# Processing Record 1 of Set 15 | sinkat
# City not found. Skipping...
# Processing Record 2 of Set 15 | felipe carrillo puerto
# Processing Record 3 of Set 15 | san andres
# Processing Record 4 of Set 15 | lysva
# Processing Record 5 of Set 15 | hit
# Processing Record 6 of Set 15 | naini tal
# Processing Record 7 of Set 15 | abalak
# Processing Record 8 of Set 15 | floresta
# Processing Record 9 of Set 15 | east hampton
# Processing Record 10 of Set 15 | viedma
# Processing Record 11 of Set 15 | praia da vitoria
# Processing Record 12 of Set 15 | ichchapuram
# Processing Record 13 of Set 15 | unye
# City not found. Skipping...
# Processing Record 14 of Set 15 | kogon
# Processing Record 15 of Set 15 | songea
# Processing Record 16 of Set 15 | maltahohe
# Processing Record 17 of Set 15 | kokomo
# Processing Record 18 of Set 15 | chiredzi
# Processing Record 19 of Set 15 | geneva
# Processing Record 20 of Set 15 | sao miguel do araguaia
# Processing Record 21 of Set 15 | nea karvali
# Processing Record 22 of Set 15 | matay
# Processing Record 23 of Set 15 | saint-denis
# Processing Record 24 of Set 15 | watford
# Processing Record 25 of Set 15 | nadym
# Processing Record 26 of Set 15 | temba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 683

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#            City      Lat      Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Castro -24.7911 -50.0119     69.91        37          41        6.06
# 1  Saint-Joseph -21.3667  55.6167     70.16        77          40       13.27
# 2       Iqaluit  63.7506 -68.5145     31.73        80          20       16.11
# 3      Yaremche  48.4583  24.5519     49.77        86         100        7.07
# 4    Vila Velha -20.3297 -40.2925     75.15        53          20       16.11
#
#     Current Weather Country                 Date
# 0  scattered clouds      BR  2021-09-23 17:23:09
# 1  scattered clouds      RE  2021-09-23 17:20:59
# 2        few clouds      CA  2021-09-23 17:20:11
# 3   overcast clouds      UA  2021-09-23 17:23:10
# 4        few clouds      BR  2021-09-23 17:23:11

# %%
new_column_order = ["City", "Country", "Lat", "Lng","Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Weather"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#            City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0        Castro      BR -24.7911 -50.0119     69.91        37          41
# 1  Saint-Joseph      RE -21.3667  55.6167     70.16        77          40
# 2       Iqaluit      CA  63.7506 -68.5145     31.73        80          20
# 3      Yaremche      UA  48.4583  24.5519     49.77        86         100
# 4    Vila Velha      BR -20.3297 -40.2925     75.15        53          20
#
#    Wind Speed   Current Weather
# 0        6.06  scattered clouds
# 1       13.27  scattered clouds
# 2       16.11        few clouds
# 3        7.07   overcast clouds
# 4       16.11        few clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
